# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movie_data = pd.read_csv(r"C:\Users\ayush\Documents\dataset\movies.dat",sep="::", engine ='python', encoding='latin1' , header=None, names=['Title','Genres'] , dtype={'Title': str, 'Genres': str})

# %%
movie_data
# Out:
#                                    Title                        Genres
# 1                       Toy Story (1995)   Animation|Children's|Comedy
# 2                         Jumanji (1995)  Adventure|Children's|Fantasy
# 3                Grumpier Old Men (1995)                Comedy|Romance
# 4               Waiting to Exhale (1995)                  Comedy|Drama
# 5     Father of the Bride Part II (1995)                        Comedy
# ...                                  ...                           ...
# 3948             Meet the Parents (2000)                        Comedy
# 3949          Requiem for a Dream (2000)                         Drama
# 3950                    Tigerland (2000)                         Drama
# 3951             Two Family House (2000)                         Drama
# 3952               Contender, The (2000)                Drama|Thriller
#
# [3883 rows x 2 columns]

# %%
ratings_data = pd.read_csv(r"C:\Users\ayush\Documents\dataset\ratings.dat",sep="::", engine ='python', encoding='latin1' , header=None, names=['UserID','MovieID','Rating','Timestamp'] , dtype={'UserID': int, 'MovieID': int, 'Rating': int, 'Timestamp' : str})

# %%
ratings_data
# Out:
#          UserID  MovieID  Rating  Timestamp
# 0             1     1193       5  978300760
# 1             1      661       3  978302109
# 2             1      914       3  978301968
# 3             1     3408       4  978300275
# 4             1     2355       5  978824291
# ...         ...      ...     ...        ...
# 1000204    6040     1091       1  956716541
# 1000205    6040     1094       5  956704887
# 1000206    6040      562       5  956704746
# 1000207    6040     1096       4  956715648
# 1000208    6040     1097       4  956715569
#
# [1000209 rows x 4 columns]

# %%
users_data=pd.read_csv(r"C:\Users\ayush\Documents\dataset\users.dat",sep="::", engine ='python', encoding='latin1' , header=None, names=['UserID','Gender','Age','Occupation','Zip-code'] , dtype={'UserID': int, 'MovieID': int, 'Rating': int, 'Timestamp' : str})

# %%
users_data
# Out:
#       UserID Gender  Age  Occupation Zip-code
# 0          1      F    1          10    48067
# 1          2      M   56          16    70072
# 2          3      M   25          15    55117
# 3          4      M   45           7    02460
# 4          5      M   25          20    55455
# ...      ...    ...  ...         ...      ...
# 6035    6036      F   25          15    32603
# 6036    6037      F   45           1    76006
# 6037    6038      F   56           1    14706
# 6038    6039      F   45           0    01060
# 6039    6040      M   25           6    11106
#
# [6040 rows x 5 columns]

# %%
ratings_movie = pd.concat([movie_data ,ratings_data], axis=1 )

# %%
ratings_movie
# Out:
#                             Title                        Genres  UserID  \
# 0                             NaN                           NaN       1
# 1                Toy Story (1995)   Animation|Children's|Comedy       1
# 2                  Jumanji (1995)  Adventure|Children's|Fantasy       1
# 3         Grumpier Old Men (1995)                Comedy|Romance       1
# 4        Waiting to Exhale (1995)                  Comedy|Drama       1
# ...                           ...                           ...     ...
# 1000204                       NaN                           NaN    6040
# 1000205                       NaN                           NaN    6040
# 1000206                       NaN                           NaN    6040
# 1000207                       NaN                           NaN    6040
# 1000208                       NaN                           NaN    6040
#
#          MovieID  Rating  Timestamp
# 0           1193       5  978300760
# ...

# %%
user_ratings = pd.merge(ratings_data,users_data, on=['UserID'])

# %%
user_ratings
# Out:
#          UserID  MovieID  Rating  Timestamp Gender  Age  Occupation Zip-code
# 0             1     1193       5  978300760      F    1          10    48067
# 1             1      661       3  978302109      F    1          10    48067
# 2             1      914       3  978301968      F    1          10    48067
# 3             1     3408       4  978300275      F    1          10    48067
# 4             1     2355       5  978824291      F    1          10    48067
# ...         ...      ...     ...        ...    ...  ...         ...      ...
# 1000204    6040     1091       1  956716541      M   25           6    11106
# 1000205    6040     1094       5  956704887      M   25           6    11106
# 1000206    6040      562       5  956704746      M   25           6    11106
# 1000207    6040     1096       4  956715648      M   25           6    11106
# 1000208    6040     1097       4  956715569      M   25           6    11106
#
# [1000209 rows x 8 columns]

# %%
master_data = pd.merge(ratings_movie,user_ratings, on=['UserID', 'MovieID', 'Rating'])

# %%
master_data
# Out:
#                             Title                        Genres  UserID  \
# 0                             NaN                           NaN       1
# 1                Toy Story (1995)   Animation|Children's|Comedy       1
# 2                  Jumanji (1995)  Adventure|Children's|Fantasy       1
# 3         Grumpier Old Men (1995)                Comedy|Romance       1
# 4        Waiting to Exhale (1995)                  Comedy|Drama       1
# ...                           ...                           ...     ...
# 1000204                       NaN                           NaN    6040
# 1000205                       NaN                           NaN    6040
# 1000206                       NaN                           NaN    6040
# 1000207                       NaN                           NaN    6040
# 1000208                       NaN                           NaN    6040
#
#          MovieID  Rating Timestamp_x Timestamp_y Gender  Age  Occupation  \
# ...

# %%
master_data=master_data.drop(['Timestamp_x','Zip-code','Genres','Timestamp_y'],axis=1)

# %%
master_data
# Out:
#                             Title  UserID  MovieID  Rating Gender  Age  \
# 0                             NaN       1     1193       5      F    1
# 1                Toy Story (1995)       1      661       3      F    1
# 2                  Jumanji (1995)       1      914       3      F    1
# 3         Grumpier Old Men (1995)       1     3408       4      F    1
# 4        Waiting to Exhale (1995)       1     2355       5      F    1
# ...                           ...     ...      ...     ...    ...  ...
# 1000204                       NaN    6040     1091       1      M   25
# 1000205                       NaN    6040     1094       5      M   25
# 1000206                       NaN    6040      562       5      M   25
# 1000207                       NaN    6040     1096       4      M   25
# 1000208                       NaN    6040     1097       4      M   25
#
#          Occupation
# 0                10
# 1                10
# 2                10
# 3                10
# ...

# %%
user_rating=ratings_data.groupby('UserID').size()

# %%
user_rating
# Out:
# UserID
# 1        53
# 2       129
# 3        51
# 4        21
# 5       198
#        ...
# 6036    888
# 6037    202
# 6038     20
# 6039    123
# 6040    341
# Length: 6040, dtype: int64

# %%
master_data['Age'].value_counts()
# Out:
# 25    395556
# 35    199003
# 18    183536
# 45     83633
# 50     72490
# 56     38780
# 1      27211
# Name: Age, dtype: int64

# %%
plt.hist(x=master_data.Age, bins=30)
plt.xlabel('Age')
plt.ylabel('Population')
plt.show()

# %%
user_rating=master_data.groupby('UserID').size()
user_rating = master_data[master_data.Title == "Toy Story (1995)"]

user_rating
# Out:
#               Title  UserID  MovieID  Rating Gender  Age  Occupation
# 1  Toy Story (1995)       1      661       3      F    1          10

# %%
from pandas_profiling import ProfileReport

# %%
profile=ProfileReport(master_data)

# %%
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
top25_movies = ratings_data.groupby(['MovieID']).size().sort_values(ascending=False)[:25]
top25_movies
plt.ylabel("MovieID")

plt.xlabel("Viewership Count")
top25_movies.plot(kind="bar")

# %%
user_rating_data=ratings_data[ratings_data['UserID']==2696]
user_rating_data

# %%
x1=movie_data['Genres'].unique()

x2=movie_data['Genres'].nunique()

x3=movie_data['Genres'].value_counts()
x3.head(10)

# %%
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder

# %%
X = df[df.columns[~df.columns.isin(["Rating"])]]
y = df.Rating

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0) 

number = LabelEncoder()
X_train.Gender = number.fit_transform(X_train["Gender"].astype("str"))
X_test.Gender = number.fit_transform(X_test["Gender"].astype("str"))
y_train = number.fit_transform(y_train.astype("int"))
y_test = number.fit_transform(y_test.astype("int"))

# %%
from sklearn.svm import SVC 
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train, y_train) 
svm_predictions = svm_model_linear.predict(X_test) 
  
  
accuracy = svm_model_linear.score(X_test, y_test) 

cm = confusion_matrix(y_test, svm_predictions) 
accuracy

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 8).fit(X_train, y_train) 
  
# accuracy on X_test 
accuracy = knn.score(X_test, y_test) 
  
# creating a confusion matrix 
knn_predictions = knn.predict(X_test)  
cm = confusion_matrix(y_test, knn_predictions) 

accuracy
